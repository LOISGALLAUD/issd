# %%
import numpy as np 
import csv
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(color_codes = True)
sns.set(font_scale=1.5) # fixe la taille de la police à 1.5 * 12pt
from scipy import stats

# %% [markdown]
# # 1. La science des données c'est quoi ?
#
# **Définitions de la donnée du [dictionnaire Larousse](https://www.larousse.fr/dictionnaires/francais/donnée/26436) :**
#
# * Ce qui est connu ou admis comme tel, sur lequel on peut fonder un raisonnement, qui sert de point de départ pour une recherche.
# * Renseignement qui sert de point d'appui.
# * Représentation conventionnelle d'une information en vue de son traitement informatique.
# * Dans un problème de mathématiques, hypothèse figurant dans l'énoncé.
# * Résultats d'observations ou d'expériences faites délibérément ou à l'occasion d'autres tâches et soumis aux méthodes statistiques.

# %% [markdown]
# <span style="color: #27AE60">**Exemple de données :**</span>
# * Documents textes numériques ou numérisés (textes, e-mails, fichiers informatiques, documents scannés et océrisés, etc.),
# * Fichiers de logs provenant de serveurs, ordinateurs, machines, etc,
# * Enregistrements par des capteurs (température, hydrométrie, etc) ou des objets connectés (rythme cardiaque, position GPS, etc),
# * Bases de données
# * Signaux, images, vidéos, etc

# %% [markdown]
# **La science des données**
#
# La science des données est par nature transdisciplinaire. Elle fait appel à plusieurs types de connaissances :
# * La discipline associée à l'application étudiée (physique, chimie, histoire, littérature, linguistique, géographie, astronomie, biologie, etc)
# * Les mathématiques pour la modélisation et l'extraction d'information
# * L'informatique pour la collecte, la sauvegarde, le stockage, le traitement et la représentation des données
#
# La science des données a pour but d'extraire de l'information d'une masse de données, de synthétiser et représenter cette information. Les différentes connaissances pour faire de la science des données peuvent être regroupées dans différentes branches. Une illustration est proposée par Swami Chandrasekaran sous la forme d'un plan de métro où chaque ligne représente une branche/discipline de la science des données.

# %% [markdown]
# ![DataScienceMap](http://nirvacana.com/thoughts/wp-content/uploads/2018/01/RoadToDataScientist1.png)
# Source de l'image : `http://nirvacana.com/thoughts/2013/07/08/becoming-a-data-scientist/`.

# %% [markdown]
# **Big data et science des données**
#
# Vous avez forcément entendu parler les termes 'big data', 'machine learning' (apprentissage automatique en français), 'deep learning', 'intelligence artificielle'. Toutes ces notions sont des sous disciplines de la science des données. Pour y voir un peu plus clair, vous pouvez regarder ces quelques vidéos mise en ligne sur Youtube (par des entreprises, des associations, des chercheurs, des villes, etc).
#
# * Le big data et le traitement de données : https://youtu.be/aq38ZLLi5Rg
#
# * Les différents types de données et leurs utilisations : https://youtu.be/sAkbabX_dec
#
# * La visualisation des données : une web-série qui met en image des données pour détruire les fake news https://youtu.be/mMvOmM9Zgos
#
# * Strasbourg à l'ère de l'open data : La ville et l'eurométropole mettent à disposition de tous des données très variées https://data.strasbourg.eu/explore/?sort=modified. On y trouve les résultats des dernières élections dans l'eurométropole, le taux d'occupation des piscines en temps réel, les arbres remarquables dans les parcs, les cartes des sentiers du Parc Naturel Urbain ou des Vita Boucles, des images, des plans, etc.
#
# Vous l'aurez compris, il est difficile de donner une définition unique des données, cela dépend de leur nature, de l'utilisation que l'on veut en faire, de la quantité d'information à notre disposition, des moyens techniques pour les traiter, etc. Dans le cadre de ce cours, nous n'aborderons qu'une infime partie de cette vaste discipline qu'est la science des données.

# %% [markdown]
# ### 1.1. A quoi servent les données
#
# Les données servent à répondre à une question. Il faut donc poser clairement la question, visualiser et modéliser les données, et les interpréter pour répondre à cette question.
#
# Les données seules ne suffisent pas à apporter une réponse. Le travail du traiteur de données consiste à inclure des connaissances a priori sur les données. Les données sont rarement neutres puisqu'on les utilise pour répondre à une question (attention au biais !).

# %% [markdown]
# ### 1.2. Un exemple de jeu de données `movie_metadata.csv`
#
# Toutes les notions abordées dans ce cours seront illustrées sur ce jeu de données réelles. Il s'agit d'un extrait de la base de données IMDb mise en ligne sur le site [kaggle](https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset).
#
# **Chargement des données avec Pandas**
#
# Utilisation du package Pandas ([Python Data Analysis Library](https://pandas.pydata.org)) qui fournit notamment l'objet DataFrame dans lequel nous allons stocker le jeu de données étudié. Cet objet DataFrame est muni d'un grand nombre de fonctions permettant :
# * la récupération et la mise en forme des données,
# * le nettoyage des données (prétraitements),
# * la représentation graphique et numérique des données,
# * l'analyse statistique des données.
#
# Consulter la documentation pour l'utilisation des fonctions de la classe DataFrame : http://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %% [markdown]
# Le jeu de données est fourni au format CSV (Comma Separated Values). C'est un format qui peut notamment être manipulé avec un tableur (Microsoft Excel ou LibreOffice Calc). Chaque ligne correspond à un film, et les différentes informations le concernant sont séparées par des point-virgules. La première ligne du fichier correspond à l'en-tête des colonnes :
#
# **En-tête**
#
# ```
# movie_title;director_name;num_critic_for_reviews;duration;actor_1_name;actor_2_name;num_voted_users;facenumber_in_poster;num_user_for_reviews;language;country;content_rating;budget;title_year;imdb_score;genres;plot_keywords
# ```
#
# **Film 1**
#
# ```
# The Shawshank Redemption;Frank Darabont;199;142;Morgan Freeman;Jeffrey DeMunn;1689764;0;4144;English;USA;R;25000000;1994;9.3;Crime|Drama;escape from prison|first person narration|prison|prison cell search|wrongful imprisonment
# ```
#
# **Film 2**
#
# ```
# The Dark Knight;Christopher Nolan;645;152;Christian Bale;Heath Ledger;1676169;0;4667;English;USA;PG-13;185000000;2008;9.0;Action|Crime|Drama|Thriller;based on comic book|dc comics|psychopath|star died before release|urban setting
# ```

# %%
DATA = pd.read_csv('../DATA/movie_metadata3.csv', delimiter=';', index_col='movie_title')
print(type(DATA))
print('Nombre de films dans la base : ' + str(len(DATA)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Nombre de films dans la base : 4125

# %% [markdown]
# La fonction `read_csv` de l'objet DataFrame est utilisée ici avec deux arguments facultatifs :
# * le paramètre `delimiter` qui permet d'indiquer comment sont séparées les valeurs dans une ligne du fichier csv,
# * le paramètre `index_col` qui permet de préciser quelle variable (= colonne) est utilisée comme identifiant pour chaque élément du fichier csv.

# %%
DATA.head(n = 15) # affiche les 15 premières lignes du DataFrame DATA.
# Out:
#                                                           director_name  \
# movie_title
# The Shawshank Redemption                                 Frank Darabont
# The Dark Knight                                       Christopher Nolan
# Inception                                             Christopher Nolan
# Fight Club                                                David Fincher
# Pulp Fiction                                          Quentin Tarantino
# Forrest Gump                                            Robert Zemeckis
# The Lord of the Rings: The Fellowship of the Ring         Peter Jackson
# The Matrix                                               Lana Wachowski
# The Lord of the Rings: The Return of the King             Peter Jackson
# The Godfather                                      Francis Ford Coppola
# The Dark Knight Rises                                 Christopher Nolan
# The Lord of the Rings: The Two Towers                     Peter Jackson
# Se7en                                                     David Fincher
# The Avengers                                                Joss Whedon
# Gladiator                                                  Ridley Scott
#
#                                                    num_critic_for_reviews  \
# movie_title
# The Shawshank Redemption                                              199
# The Dark Knight                                                       645
# Inception                                                             642
# Fight Club                                                            315
# Pulp Fiction                                                          215
# Forrest Gump                                                          149
# The Lord of the Rings: The Fellowship of the Ring                     297
# The Matrix                                                            313
# The Lord of the Rings: The Return of the King                         328
# The Godfather                                                         208
# The Dark Knight Rises                                                 813
# The Lord of the Rings: The Two Towers                                 294
# Se7en                                                                 216
# The Avengers                                                          703
# Gladiator                                                             265
#
#                                                    duration  \
# movie_title
# The Shawshank Redemption                                142
# The Dark Knight                                         152
# Inception                                               148
# Fight Club                                              151
# Pulp Fiction                                            178
# Forrest Gump                                            142
# The Lord of the Rings: The Fellowship of the Ring       171
# The Matrix                                              136
# The Lord of the Rings: The Return of the King           192
# The Godfather                                           175
# The Dark Knight Rises                                   164
# The Lord of the Rings: The Two Towers                   172
# Se7en                                                   127
# The Avengers                                            173
# Gladiator                                               171
#
#                                                         actor_1_name  \
# movie_title
# The Shawshank Redemption                              Morgan Freeman
# The Dark Knight                                       Christian Bale
# Inception                                          Leonardo DiCaprio
# Fight Club                                                 Brad Pitt
# Pulp Fiction                                            Bruce Willis
# Forrest Gump                                               Tom Hanks
# The Lord of the Rings: The Fellowship of the Ring    Christopher Lee
# The Matrix                                              Keanu Reeves
# The Lord of the Rings: The Return of the King          Orlando Bloom
# The Godfather                                              Al Pacino
# The Dark Knight Rises                                      Tom Hardy
# The Lord of the Rings: The Two Towers                Christopher Lee
# Se7en                                                 Morgan Freeman
# The Avengers                                         Chris Hemsworth
# Gladiator                                             Djimon Hounsou
#
#                                                            actor_2_name  \
# movie_title
# The Shawshank Redemption                                 Jeffrey DeMunn
# The Dark Knight                                            Heath Ledger
# Inception                                                     Tom Hardy
# Fight Club                                                    Meat Loaf
# Pulp Fiction                                                Eric Stoltz
# Forrest Gump                                       Siobhan Fallon Hogan
# The Lord of the Rings: The Fellowship of the Ring         Orlando Bloom
# The Matrix                                                 Marcus Chong
# The Lord of the Rings: The Return of the King                Billy Boyd
# The Godfather                                             Marlon Brando
# The Dark Knight Rises                                    Christian Bale
# The Lord of the Rings: The Two Towers                     Orlando Bloom
# Se7en                                                         Brad Pitt
# The Avengers                                          Robert Downey Jr.
# Gladiator                                                Connie Nielsen
#
#                                                    num_voted_users  \
# movie_title
# The Shawshank Redemption                                   1689764
# The Dark Knight                                            1676169
# Inception                                                  1468200
# Fight Club                                                 1347461
# Pulp Fiction                                               1324680
# Forrest Gump                                               1251222
# The Lord of the Rings: The Fellowship of the Ring          1238746
# The Matrix                                                 1217752
# The Lord of the Rings: The Return of the King              1215718
# The Godfather                                              1155770
# The Dark Knight Rises                                      1144337
# The Lord of the Rings: The Two Towers                      1100446
# Se7en                                                      1023511
# The Avengers                                                995415
# Gladiator                                                   982637
#
#                                                    facenumber_in_poster  \
# movie_title
# The Shawshank Redemption                                              0
# The Dark Knight                                                       0
# Inception                                                             0
# Fight Club                                                            2
# Pulp Fiction                                                          1
# Forrest Gump                                                          0
# The Lord of the Rings: The Fellowship of the Ring                     2
# The Matrix                                                            3
# The Lord of the Rings: The Return of the King                         2
# The Godfather                                                         1
# The Dark Knight Rises                                                 0
# The Lord of the Rings: The Two Towers                                 1
# Se7en                                                                 0
# The Avengers                                                          3
# Gladiator                                                             0
#
#                                                    num_user_for_reviews  \
# movie_title
# The Shawshank Redemption                                           4144
# The Dark Knight                                                    4667
# Inception                                                          2803
# Fight Club                                                         2968
# Pulp Fiction                                                       2195
# Forrest Gump                                                       1398
# The Lord of the Rings: The Fellowship of the Ring                  5060
# The Matrix                                                         3646
# The Lord of the Rings: The Return of the King                      3189
# The Godfather                                                      2238
# The Dark Knight Rises                                              2701
# The Lord of the Rings: The Two Towers                              2417
# Se7en                                                              1080
# The Avengers                                                       1722
# Gladiator                                                          2368
#
#                                                   language      country  \
# movie_title
# The Shawshank Redemption                           English          USA
# The Dark Knight                                    English          USA
# Inception                                          English          USA
# Fight Club                                         English          USA
# Pulp Fiction                                       English          USA
# Forrest Gump                                       English          USA
# The Lord of the Rings: The Fellowship of the Ring  English  New Zealand
# The Matrix                                         English          USA
# The Lord of the Rings: The Return of the King      English          USA
# The Godfather                                      English          USA
# The Dark Knight Rises                              English          USA
# The Lord of the Rings: The Two Towers              English          USA
# Se7en                                              English          USA
# The Avengers                                       English          USA
# Gladiator                                          English          USA
#
#                                                   content_rating     budget  \
# movie_title
# The Shawshank Redemption                                       R   25000000
# The Dark Knight                                            PG-13  185000000
# Inception                                                  PG-13  160000000
# Fight Club                                                     R   63000000
# Pulp Fiction                                                   R    8000000
# Forrest Gump                                               PG-13   55000000
# The Lord of the Rings: The Fellowship of the Ring          PG-13   93000000
# The Matrix                                                     R   63000000
# The Lord of the Rings: The Return of the King              PG-13   94000000
# The Godfather                                                  R    6000000
# The Dark Knight Rises                                      PG-13  250000000
# The Lord of the Rings: The Two Towers                      PG-13   94000000
# Se7en                                                          R   33000000
# The Avengers                                               PG-13  220000000
# Gladiator                                                      R  103000000
#
#                                                    title_year  imdb_score  \
# movie_title
# The Shawshank Redemption                                 1994         9.3
# The Dark Knight                                          2008         9.0
# Inception                                                2010         8.8
# Fight Club                                               1999         8.8
# Pulp Fiction                                             1994         8.9
# Forrest Gump                                             1994         8.8
# The Lord of the Rings: The Fellowship of the Ring        2001         8.8
# The Matrix                                               1999         8.7
# The Lord of the Rings: The Return of the King            2003         8.9
# The Godfather                                            1972         9.2
# The Dark Knight Rises                                    2012         8.5
# The Lord of the Rings: The Two Towers                    2002         8.7
# Se7en                                                    1995         8.6
# The Avengers                                             2012         8.1
# Gladiator                                                2000         8.5
#
#                                                                              genres  \
# movie_title
# The Shawshank Redemption                                                Crime|Drama
# The Dark Knight                                         Action|Crime|Drama|Thriller
# Inception                                          Action|Adventure|Sci-Fi|Thriller
# Fight Club                                                                    Drama
# Pulp Fiction                                                            Crime|Drama
# Forrest Gump                                                           Comedy|Drama
# The Lord of the Rings: The Fellowship of the Ring    Action|Adventure|Drama|Fantasy
# The Matrix                                                            Action|Sci-Fi
# The Lord of the Rings: The Return of the King        Action|Adventure|Drama|Fantasy
# The Godfather                                                           Crime|Drama
# The Dark Knight Rises                                               Action|Thriller
# The Lord of the Rings: The Two Towers                Action|Adventure|Drama|Fantasy
# Se7en                                                  Crime|Drama|Mystery|Thriller
# The Avengers                                                Action|Adventure|Sci-Fi
# Gladiator                                                      Action|Drama|Romance
#
#                                                                                        plot_keywords
# movie_title
# The Shawshank Redemption                           escape from prison|first person narration|pris...
# The Dark Knight                                    based on comic book|dc comics|psychopath|star ...
# Inception                                          ambiguous ending|corporate espionage|dream|sub...
# Fight Club                                         anti establishment|dark humor|fighting|multipl...
# Pulp Fiction                                       black comedy|cunnilingus|neo noir|nonlinear ti...
# Forrest Gump                                               amputee|love|vietnam|vietnam war|war hero
# The Lord of the Rings: The Fellowship of the Ring                 elf|hobbit|middle earth|quest|ring
# The Matrix                                         artificial reality|computer|matrix|questioning...
# The Lord of the Rings: The Return of the King                              battle|epic|king|orc|ring
# The Godfather                                      crime family|mafia|organized crime|patriarch|r...
# The Dark Knight Rises                              deception|imprisonment|lawlessness|police offi...
# The Lord of the Rings: The Two Towers                      epic|evil wizard|middle earth|ring|wizard
# Se7en                                              detective|police partner|serial killer|serial ...
# The Avengers                                         alien invasion|assassin|battle|iron man|soldier
# Gladiator                                            battlefield|blood|combat|gladiator|roman empire

# %% [markdown]
# # 2. Vocabulaire utile
#
# Afin de parler le même langage, on donne ici quelques définitions/rappels de statistiques :
#
# **Population :** Totalité des individus ou des objets étudiés.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
# **Échantillon :** Sous-ensemble d’individus ou d’objets étudiés.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
# **Individu :** élément d’une population.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
# **Variable(s) :** on parle aussi de caractère(s). Une variable $X$ représente une
# caractéristique dont on observe/recueille la valeur pour chaque
# individu d’une population. Une population peut être caractérisée par
# une (analyse unidimensionnelle) ou plusieurs variables (analyse
# multidimensionnelle). La variable statistique (ou aléatoire) est notée
# en majuscule $X$, les valeurs qu’elle prend sont notées en minuscules $(x_1, x_2, \cdots)$.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
# **Valeurs :** ce sont les valeurs numériques ou modalités $(x_1, x_2, \cdots)$ prises par la
# variable d’intérêt $X$ pour les $N$ individus de l'échantillon.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...

# %% [markdown]
# **Effectif :** nombre d’individus de l'échantillon pour lesquels la variable $X$
# prend une valeur donnée $x_i$.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
# **Fréquence :** la fréquence $f_i$ associée à la valeur $x_i$ est le rapport de l’effectif de
# cette valeur sur la taille $N$ de l'échantillon. La somme des
# fréquences est égale à 1 (ou 100 si l’on travaille en $\%$).
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...
#
#
# **Etendue :** Soit $(x_1, x_2, \cdots, x_N)$ un ensemble de valeurs. Notons $x_{max}$ la valeur
# maximale de l’ensemble $(x_1, x_2, \cdots, x_N)$ et $x_{min}$ la valeur minimale. On
# appelle étendue de l’ensemble de valeurs $(x_1, x_2, \cdots, x_N)$ la différence
# $x_{max} - x_{min}$.
#
# <span style="color: #27AE60">exemple :</span>
# ... A compléter ...

# %% [markdown]
# # 3. Les différents types de données

# %% [markdown]
# ### 3.1. Données quantitatives
#
# Ce sont des quantités mesurables sur lesquelles on peut faire des calculs et des comparaisons : $ f(x), \div, \times, =, \neq, \leqslant, \geqslant$.
#
# Une variable quantitative peut être soit continue $x \in [a,b]$ soit discrète $x\in \{a,b,c, \dots\}$
#
# <span style="color: #27AE60">Exemple de données quantitatives continue dans la base IMdB :</span>
#
# ... A compléter ...
#
# <span style="color: #27AE60">Exemple de données quantitatives discrète dans la base IMdB :</span>
#
# ... A compléter ...

# %% [markdown]
# ### 3.2. Données qualitatives
#
# Ce sont des caractéristiques non mesurables, on parle de modalités.
# Une variable qualitative peut être soit nominale, dans ce cas il n'y a pas de notion d'ordre, les seules opérations autorisées sont : $=, \neq$, soit ordinale, on peut ajouter aux opérations $=$ et $\neq$ le tri (ordre logique)
#
# <span style="color: #27AE60">Exemple de données qualitatives nominales dans la base IMdB :</span>
#
# ... A compléter ...
#
# <span style="color: #27AE60">Exemple de données qualitatives ordinales dans la base IMdB :</span>
#
# ... A compléter ...

# %% [markdown]
# # Filtrage des données

# %% [markdown]
# Nous allons voir comment filtrer les données en fonction de divers types de critères.
#
# Prenons tout d'abord l'exemple du genre des films, afin de constituer des tables de données ne regroupant que des films d'un genre particulier.
#
# Exemple pour les films d'action :

# %%
# On ne conserve que les films tels que la colonne 'genres'
# contient le mot "Action"
action_movies = DATA[DATA['genres'].str.contains("Action", na=False)]
action_movies.head()[['genres']]
# Out:
#                                                                              genres
# movie_title
# The Dark Knight                                         Action|Crime|Drama|Thriller
# Inception                                          Action|Adventure|Sci-Fi|Thriller
# The Lord of the Rings: The Fellowship of the Ring    Action|Adventure|Drama|Fantasy
# The Matrix                                                            Action|Sci-Fi
# The Lord of the Rings: The Return of the King        Action|Adventure|Drama|Fantasy

# %% [markdown]
# Ce type de filtrage peut également être appliqué à l'index (`movie_title`), par exemple tous les titres qui contiennent le mot 'Batman' :

# %%
batman_movies = DATA[DATA.index.str.contains('Batman')]
batman_movies.head()
# Out:
#                                         director_name  num_critic_for_reviews  \
# movie_title
# Batman Begins                       Christopher Nolan                     478
# Batman v Superman: Dawn of Justice        Zack Snyder                     673
# Batman                                     Tim Burton                     186
# Batman Returns                             Tim Burton                     153
# Batman Forever                        Joel Schumacher                     144
#
#                                     duration    actor_1_name  \
# movie_title
# Batman Begins                            128  Christian Bale
# Batman v Superman: Dawn of Justice       183    Henry Cavill
# Batman                                   126   Michael Gough
# Batman Returns                           126   Michael Gough
# Batman Forever                           121   Michael Gough
#
#                                           actor_2_name  num_voted_users  \
# movie_title
# Batman Begins                              Liam Neeson           980946
# Batman v Superman: Dawn of Justice        Lauren Cohan           371639
# Batman                                    Jack Palance           269033
# Batman Returns                      Vincent Schiavelli           215255
# Batman Forever                        Rene Auberjonois           190786
#
#                                     facenumber_in_poster  \
# movie_title
# Batman Begins                                          0
# Batman v Superman: Dawn of Justice                     0
# Batman                                                 0
# Batman Returns                                         0
# Batman Forever                                         4
#
#                                     num_user_for_reviews language country  \
# movie_title
# Batman Begins                                       2685  English     USA
# Batman v Superman: Dawn of Justice                  3018  English     USA
# Batman                                               817  English     USA
# Batman Returns                                       610  English     USA
# Batman Forever                                       539  English     USA
#
#                                    content_rating     budget  title_year  \
# movie_title
# Batman Begins                               PG-13  150000000        2005
# Batman v Superman: Dawn of Justice          PG-13  250000000        2016
# Batman                                      PG-13   35000000        1989
# Batman Returns                              PG-13   80000000        1992
# Batman Forever                              PG-13  100000000        1995
#
#                                     imdb_score                    genres  \
# movie_title
# Batman Begins                              8.3          Action|Adventure
# Batman v Superman: Dawn of Justice         6.9   Action|Adventure|Sci-Fi
# Batman                                     7.6          Action|Adventure
# Batman Returns                             7.0                    Action
# Batman Forever                             5.4  Action|Adventure|Fantasy
#
#                                                                         plot_keywords
# movie_title
# Batman Begins                       armored car|gangster|gotham|mixed martial arts...
# Batman v Superman: Dawn of Justice  based on comic book|batman|sequel to a reboot|...
# Batman                                         city|dc comics|gotham|pantyhose|police
# Batman Returns                          box office hit|dc comics|gotham|mayor|penguin
# Batman Forever                                 love|necktie|partner|rock music|tuxedo

# %% [markdown]
# On peut aussi vérifier qu'une chaîne commence par une sous-chaîne donnée :

# %%
snow_movies = DATA[DATA.index.str.startswith('Snow')]
snow_movies.head()
# Out:
#                                     director_name  num_critic_for_reviews  \
# movie_title
# Snow White and the Huntsman        Rupert Sanders                     416
# Snowpiercer                          Joon-ho Bong                     488
# Snow White and the Seven Dwarfs  William Cottrell                     145
# Snow Dogs                            Brian Levant                      67
# Snow Falling on Cedars                Scott Hicks                      95
#
#                                  duration       actor_1_name  \
# movie_title
# Snow White and the Huntsman           132    Chris Hemsworth
# Snowpiercer                           126        Chris Evans
# Snow White and the Seven Dwarfs        83  Adriana Caselotti
# Snow Dogs                              99       James Coburn
# Snow Falling on Cedars                127          Rick Yune
#
#                                      actor_2_name  num_voted_users  \
# movie_title
# Snow White and the Huntsman       Kristen Stewart           228554
# Snowpiercer                          Ewen Bremner           181472
# Snow White and the Seven Dwarfs     Billy Gilbert           133348
# Snow Dogs                        Nichelle Nichols            20219
# Snow Falling on Cedars               Reeve Carney            12375
#
#                                  facenumber_in_poster  num_user_for_reviews  \
# movie_title
# Snow White and the Huntsman                         0                   710
# Snowpiercer                                         5                   514
# Snow White and the Seven Dwarfs                     1                   204
# Snow Dogs                                           1                   100
# Snow Falling on Cedars                              1                   194
#
#                                 language      country content_rating  \
# movie_title
# Snow White and the Huntsman      English          USA          PG-13
# Snowpiercer                      English  South Korea              R
# Snow White and the Seven Dwarfs  English          USA       Approved
# Snow Dogs                        English       Canada             PG
# Snow Falling on Cedars           English          USA          PG-13
#
#                                     budget  title_year  imdb_score  \
# movie_title
# Snow White and the Huntsman      170000000        2012         6.1
# Snowpiercer                       39200000        2013         7.0
# Snow White and the Seven Dwarfs    2000000        1937         7.7
# Snow Dogs                         35000000        2002         5.1
# Snow Falling on Cedars            36000000        1999         6.8
#
#                                                            genres  \
# movie_title
# Snow White and the Huntsman        Action|Adventure|Drama|Fantasy
# Snowpiercer                          Action|Drama|Sci-Fi|Thriller
# Snow White and the Seven Dwarfs  Animation|Family|Fantasy|Musical
# Snow Dogs                           Adventure|Comedy|Family|Sport
# Snow Falling on Cedars             Drama|Mystery|Romance|Thriller
#
#                                                                      plot_keywords
# movie_title
# Snow White and the Huntsman           evil queen|fairy tale|magic|queen|snow white
# Snowpiercer                      closed ecological system|perpetual winter|popu...
# Snow White and the Seven Dwarfs               dwarf|love|princess|queen|snow white
# Snow Dogs                                    dentist|dog|inheritance|race|sled dog
# Snow Falling on Cedars              fisherman|japanese|love|trial|washington state

# %% [markdown]
# On peut aussi vérifier qu'une chaîne se termine par une sous-chaîne donnée :

# %%
games_movies = DATA[DATA.index.str.endswith('Games')]
games_movies.head()
# Out:
#                        director_name  num_critic_for_reviews  duration  \
# movie_title
# The Hunger Games           Gary Ross                     673       142
# Patriot Games          Phillip Noyce                      47       117
# WarGames                 John Badham                      84       114
# Funny Games           Michael Haneke                     250       111
# Reindeer Games    John Frankenheimer                     126       124
#
#                        actor_1_name          actor_2_name  num_voted_users  \
# movie_title
# The Hunger Games  Jennifer Lawrence       Josh Hutcherson           701607
# Patriot Games         Harrison Ford          Polly Walker            81442
# WarGames          Matthew Broderick          Barry Corbin            71842
# Funny Games             Naomi Watts  Siobhan Fallon Hogan            69569
# Reindeer Games      Charlize Theron           James Frain            31113
#
#                   facenumber_in_poster  num_user_for_reviews language country  \
# movie_title
# The Hunger Games                     0                  1959  English     USA
# Patriot Games                        1                   137  English     USA
# WarGames                             0                   152  English     USA
# Funny Games                          0                   436  English     USA
# Reindeer Games                       0                   212  English     USA
#
#                  content_rating    budget  title_year  imdb_score  \
# movie_title
# The Hunger Games          PG-13  78000000        2012         7.3
# Patriot Games                 R  45000000        1992         6.9
# WarGames                     PG  12000000        1983         7.1
# Funny Games                   R  15000000        2007         6.5
# Reindeer Games                R  34000000        2000         5.7
#
#                                                              genres  \
# movie_title
# The Hunger Games                    Adventure|Drama|Sci-Fi|Thriller
# Patriot Games                                       Action|Thriller
# WarGames                                            Sci-Fi|Thriller
# Funny Games                             Crime|Drama|Horror|Thriller
# Reindeer Games    Action|Adventure|Crime|Drama|Family|Fantasy|Ro...
#
#                                                       plot_keywords
# movie_title
# The Hunger Games  fight to the death|game|massacre|self survival...
# Patriot Games            analyst|cia|ira|terrorist|terrorist attack
# WarGames                   computer|game|high school|norad|teenager
# Funny Games       breaking the fourth wall|looking at the camera...
# Reindeer Games    casino|christmas|christmas season|girlfriend|r...

# %% [markdown]
# Pour les colonnes numériques, on pourra utiliser les opérateurs relationnels :
#
# - `<`
# - `<=`
# - `>`
# - `>=`
# - `==`
# - `!=`
#
# Par exemple, pour les films d'action qui durent plus de 3 heures (180 minutes) :

# %%
long_action_movies = action_movies[action_movies['duration'] > 180]
# Autre syntaxe possible : 
# long_action_movies = action_movies[action_movies.duration > 180]
long_action_movies.head()[['genres', 'duration']] # permet d'afficher uniquement les colonnes 'genres' et 'duration'
# Out:
#                                                                        genres  \
# movie_title
# The Lord of the Rings: The Return of the King  Action|Adventure|Drama|Fantasy
# Iron Man 3                                            Action|Adventure|Sci-Fi
# Watchmen                                          Action|Drama|Mystery|Sci-Fi
# Batman v Superman: Dawn of Justice                    Action|Adventure|Sci-Fi
# King Kong                                      Action|Adventure|Drama|Romance
#
#                                                duration
# movie_title
# The Lord of the Rings: The Return of the King       192
# Iron Man 3                                          195
# Watchmen                                            215
# Batman v Superman: Dawn of Justice                  183
# King Kong                                           201

# %% [markdown]
# Ces critères peuvent aussi être combinés directement à l'aide d'opérateurs logiques (et : `&`, ou : `|`). Dans cas, il faut entourer chaque condition par des parenthèses :

# %%
long_action_movies2 = DATA[(DATA['genres'].str.contains("Action")) & (DATA['duration'] > 180)]
long_action_movies2.head()[['genres', 'duration']]
# Out:
#                                                                        genres  \
# movie_title
# The Lord of the Rings: The Return of the King  Action|Adventure|Drama|Fantasy
# Iron Man 3                                            Action|Adventure|Sci-Fi
# Watchmen                                          Action|Drama|Mystery|Sci-Fi
# Batman v Superman: Dawn of Justice                    Action|Adventure|Sci-Fi
# King Kong                                      Action|Adventure|Drama|Romance
#
#                                                duration
# movie_title
# The Lord of the Rings: The Return of the King       192
# Iron Man 3                                          195
# Watchmen                                            215
# Batman v Superman: Dawn of Justice                  183
# King Kong                                           201

# %% [markdown]
# Le 'ou' pourra être utilisé par exemple dans le cas suivant : films dans lesquels Salma Hayek est soit l'actrice principale, soit l'actrice secondaire :

# %%
condition1 = DATA['actor_1_name'] == 'Salma Hayek'
condition2 = DATA['actor_2_name'] == 'Salma Hayek'
salma_hayek = DATA[condition1 | condition2]
salma_hayek.head(n=10)[['actor_1_name', 'actor_2_name']]
# Out:
#                                   actor_1_name     actor_2_name
# movie_title
# From Dusk Till Dawn          Quentin Tarantino      Salma Hayek
# Once Upon a Time in Mexico         Johnny Depp      Salma Hayek
# Wild Wild West                      Will Smith      Salma Hayek
# Puss in Boots                      Salma Hayek  Constance Marie
# The Faculty                   Jordana Brewster      Salma Hayek
# Four Rooms                         Salma Hayek      Alicia Witt
# Here Comes the Boom                Salma Hayek       Reggie Lee
# Frida                              Salma Hayek       Roger Rees
# Spy Kids 3-D: Game Over     Sylvester Stallone      Salma Hayek
# After the Sunset                   Salma Hayek      Don Cheadle

# %% [markdown]
# Si l'on cherche la présence de plusieurs valeurs dans la même colonne, on pourra utiliser `isin`. Par exemple, pour chercher les films dont l'acteur principal est soit "Sylvester Stallone", soit "Will Smith", soit "Bruce Willis" :

# %%
actors = ["Sylvester Stallone", "Will Smith", "Bruce Willis"]
actors_movies = DATA[DATA['actor_1_name'].isin(actors)]
actors_movies.head(n=20)[['actor_1_name', 'genres']]
# Out:
#                                  actor_1_name  \
# movie_title
# Pulp Fiction                     Bruce Willis
# The Sixth Sense                  Bruce Willis
# I Am Legend                        Will Smith
# Independence Day                   Will Smith
# Men in Black                       Will Smith
# I  Robot                           Will Smith
# Rocky                      Sylvester Stallone
# Hancock                            Will Smith
# The Pursuit of Happyness           Will Smith
# Live Free or Die Hard            Bruce Willis
# Armageddon                       Bruce Willis
# Die Hard with a Vengeance        Bruce Willis
# Men in Black II                    Will Smith
# Die Hard 2                       Bruce Willis
# Men in Black 3                     Will Smith
# Lucky Number Slevin              Bruce Willis
# Hitch                              Will Smith
# RED                              Bruce Willis
# Moonrise Kingdom                 Bruce Willis
# Seven Pounds                       Will Smith
#
#                                                                       genres
# movie_title
# Pulp Fiction                                                     Crime|Drama
# The Sixth Sense                                       Drama|Mystery|Thriller
# I Am Legend                                              Drama|Horror|Sci-Fi
# Independence Day                                     Action|Adventure|Sci-Fi
# Men in Black                          Adventure|Comedy|Family|Mystery|Sci-Fi
# I  Robot                                      Action|Mystery|Sci-Fi|Thriller
# Rocky                                                            Drama|Sport
# Hancock                                                         Action|Drama
# The Pursuit of Happyness                                     Biography|Drama
# Live Free or Die Hard                              Action|Adventure|Thriller
# Armageddon                                  Action|Adventure|Sci-Fi|Thriller
# Die Hard with a Vengeance                          Action|Adventure|Thriller
# Men in Black II            Action|Adventure|Comedy|Family|Fantasy|Mystery...
# Die Hard 2                                                   Action|Thriller
# Men in Black 3                 Action|Adventure|Comedy|Family|Fantasy|Sci-Fi
# Lucky Number Slevin                             Crime|Drama|Mystery|Thriller
# Hitch                                                         Comedy|Romance
# RED                                             Action|Comedy|Crime|Thriller
# Moonrise Kingdom                              Adventure|Comedy|Drama|Romance
# Seven Pounds                                                   Drama|Romance

# %% [markdown]
# On peut construire des groupes par valeur d'une ou plusieurs colonnes, et leur appliquer des fonctions d'agrégation. Par exemple, dans quelles langues sont les films tournés aux États-Unis et combien sont-ils par langue ?

# %%
countries_languages = DATA[DATA['country'] == 'USA'].groupby(['language'])
countries_languages.size()
# Out:
# language
# Aramaic          1
# Bosnian          1
# Dari             1
# English       3209
# Filipino         1
# Japanese         1
# Maya             1
# None             1
# Spanish          6
# Vietnamese       1
# dtype: int64

# %% [markdown]
# ## Mise en pratique pendant la séance
#
# Répondez aux questions suivantes :
# 1. Quels sont les films postérieurs à 2004 ?
# 2. Quels sont les films dont le budget est inférieur à 1 million de dollars ?
# 3. Quels sont les films qui sont sortis en 2013 ?
# 4. Quels sont les films qui ont été réalisés par Quentin Tarantino ?
# 5. Quels sont les films français ?
# 6. Quels sont les films qui parlent de dragons ? (voir la colonne `plot_keywords`)
# 7. Quels sont les films de la saga Star Wars ?
# 8. Quels sont les films qui ont un score supérieur à 9 ?
# 9. Quels sont les films de science-fiction réalisés par James Cameron ?
# 10. Quels sont les films français qui ont un score supérieur à 8 ?
# 11. Quels sont les films d'action avec Leonardo Di Caprio comme acteur principal ou secondaire ?
# 12. Quels sont les westerns qui parlent d'esclavage (*slavery*) ?
# 13. Quels sont les films d'action en anglais qui parlent d'ordinateurs (*computer*) ?
# 14. Quels sont les films allemands, mais en anglais, dont la note est supérieure à 6 ?
# 15. Quels sont les films dont l'acteur principal a pour prénom 'Jonathan' et l'actrice secondaire 'Elizabeth' ?

# %%
# 1
films_after_2004 = DATA[DATA['title_year'] > 2004]
films_after_2004.head()[['title_year']]
# Out:
#                        title_year
# movie_title
# The Dark Knight              2008
# Inception                    2010
# The Dark Knight Rises        2012
# The Avengers                 2012
# Batman Begins                2005

# %%
# 2
films_budget_under_million = DATA[DATA['budget'] < 1000000]
films_budget_under_million.head()[['budget']]
# Out:
#                                     budget
# movie_title
# 12 Angry Men                        350000
# Psycho                              806947
# Lock Stock and Two Smoking Barrels  960000
# Casablanca                          950000
# Monty Python and the Holy Grail     229575

# %%
# 3
film_in_2013 = DATA[DATA['title_year'] == 2013]
film_in_2013.head()[['title_year']]
# Out:
#                                  title_year
# movie_title
# The Wolf of Wall Street                2013
# Gravity                                2013
# Iron Man 3                             2013
# Man of Steel                           2013
# The Hunger Games: Catching Fire        2013

# %%
# 4
films_tarantino = DATA[DATA['director_name'] == 'Quentin Tarantino']
films_tarantino.head()[['director_name']]
# Out:
#                           director_name
# movie_title
# Pulp Fiction          Quentin Tarantino
# Django Unchained      Quentin Tarantino
# Inglourious Basterds  Quentin Tarantino
# Kill Bill: Vol. 1     Quentin Tarantino
# Reservoir Dogs        Quentin Tarantino

# %%
# 5
films_francais = DATA[DATA['country'] == 'France']
films_francais.head()[['country']]
# Out:
#                   country
# movie_title
# Amélie             France
# The Pianist        France
# Taken              France
# The Fifth Element  France
# Lucy               France

# %%
# 6
dragon_films = DATA[DATA['plot_keywords'].str.contains('dragon', na=False)]
dragon_films.head()[['plot_keywords']]
# Out:
#                                                                        plot_keywords
# movie_title
# The Hobbit: An Unexpected Journey                     dragon|dwarf|hobbit|orc|wizard
# How to Train Your Dragon                       dragon|island|training|viking|village
# How to Train Your Dragon 2         dragon|father son relationship|husband wife re...
# Eragon                             dragon|dragon rider|fictional war|sword and fa...
# Reign of Fire                      castle|dragon|fire breathing dragon|militia|su...

# %%
# 7
star_wars_films = DATA[DATA.index.str.contains('Star Wars')]
star_wars_films.head()
# Out:
#                                                    director_name  \
# movie_title
# Star Wars: Episode IV - A New Hope                  George Lucas
# Star Wars: Episode V - The Empire Strikes Back    Irvin Kershner
# Star Wars: Episode VI - Return of the Jedi      Richard Marquand
# Star Wars: Episode I - The Phantom Menace           George Lucas
# Star Wars: Episode III - Revenge of the Sith        George Lucas
#
#                                                 num_critic_for_reviews  \
# movie_title
# Star Wars: Episode IV - A New Hope                                 282
# Star Wars: Episode V - The Empire Strikes Back                     223
# Star Wars: Episode VI - Return of the Jedi                         197
# Star Wars: Episode I - The Phantom Menace                          320
# Star Wars: Episode III - Revenge of the Sith                       359
#
#                                                 duration     actor_1_name  \
# movie_title
# Star Wars: Episode IV - A New Hope                   125    Harrison Ford
# Star Wars: Episode V - The Empire Strikes Back       127    Harrison Ford
# Star Wars: Episode VI - Return of the Jedi           134    Harrison Ford
# Star Wars: Episode I - The Phantom Menace            136  Natalie Portman
# Star Wars: Episode III - Revenge of the Sith         140  Natalie Portman
#
#                                                    actor_2_name  \
# movie_title
# Star Wars: Episode IV - A New Hope                Peter Cushing
# Star Wars: Episode V - The Empire Strikes Back      Kenny Baker
# Star Wars: Episode VI - Return of the Jedi        Ian McDiarmid
# Star Wars: Episode I - The Phantom Menace           Liam Neeson
# Star Wars: Episode III - Revenge of the Sith    Christopher Lee
#
#                                                 num_voted_users  \
# movie_title
# Star Wars: Episode IV - A New Hope                       911097
# Star Wars: Episode V - The Empire Strikes Back           837759
# Star Wars: Episode VI - Return of the Jedi               681857
# Star Wars: Episode I - The Phantom Menace                534658
# Star Wars: Episode III - Revenge of the Sith             520104
#
#                                                 facenumber_in_poster  \
# movie_title
# Star Wars: Episode IV - A New Hope                                 1
# Star Wars: Episode V - The Empire Strikes Back                     0
# Star Wars: Episode VI - Return of the Jedi                         0
# Star Wars: Episode I - The Phantom Menace                          1
# Star Wars: Episode III - Revenge of the Sith                       4
#
#                                                 num_user_for_reviews language  \
# movie_title
# Star Wars: Episode IV - A New Hope                              1470  English
# Star Wars: Episode V - The Empire Strikes Back                   900  English
# Star Wars: Episode VI - Return of the Jedi                       647  English
# Star Wars: Episode I - The Phantom Menace                       3597  English
# Star Wars: Episode III - Revenge of the Sith                    3286  English
#
#                                                country content_rating  \
# movie_title
# Star Wars: Episode IV - A New Hope                 USA             PG
# Star Wars: Episode V - The Empire Strikes Back     USA             PG
# Star Wars: Episode VI - Return of the Jedi         USA             PG
# Star Wars: Episode I - The Phantom Menace          USA             PG
# Star Wars: Episode III - Revenge of the Sith       USA          PG-13
#
#                                                    budget  title_year  \
# movie_title
# Star Wars: Episode IV - A New Hope               11000000        1977
# Star Wars: Episode V - The Empire Strikes Back   18000000        1980
# Star Wars: Episode VI - Return of the Jedi       32500000        1983
# Star Wars: Episode I - The Phantom Menace       115000000        1999
# Star Wars: Episode III - Revenge of the Sith    113000000        2005
#
#                                                 imdb_score  \
# movie_title
# Star Wars: Episode IV - A New Hope                     8.7
# Star Wars: Episode V - The Empire Strikes Back         8.8
# Star Wars: Episode VI - Return of the Jedi             8.4
# Star Wars: Episode I - The Phantom Menace              6.5
# Star Wars: Episode III - Revenge of the Sith           7.6
#
#                                                                          genres  \
# movie_title
# Star Wars: Episode IV - A New Hope              Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode V - The Empire Strikes Back  Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode VI - Return of the Jedi      Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode I - The Phantom Menace       Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode III - Revenge of the Sith    Action|Adventure|Fantasy|Sci-Fi
#
#                                                                                     plot_keywords
# movie_title
# Star Wars: Episode IV - A New Hope              death star|empire|galactic war|princess|rebellion
# Star Wars: Episode V - The Empire Strikes Back     duel|famous twist|rebel|rescue|snowy landscape
# Star Wars: Episode VI - Return of the Jedi               death star|emperor|empire|princess|rebel
# Star Wars: Episode I - The Phantom Menace       alien|character says i have a bad feeling abou...
# Star Wars: Episode III - Revenge of the Sith    elongated cry of no|friends become enemies|kic...

# %%
# 8
films_score_above_9 = DATA[DATA['imdb_score'] > 9]
films_score_above_9.head()[['imdb_score']]
# Out:
#                           imdb_score
# movie_title
# The Shawshank Redemption         9.3
# The Godfather                    9.2

# %%
# 9
films_Cameron_sf = DATA[(DATA['director_name'] == 'James Cameron') & (DATA['genres'].str.contains('Sci-Fi'))]
films_Cameron_sf.head()[['director_name', 'genres']]
# Out:
#                             director_name                           genres
# movie_title
# Avatar                      James Cameron  Action|Adventure|Fantasy|Sci-Fi
# Terminator 2: Judgment Day  James Cameron                    Action|Sci-Fi
# The Terminator              James Cameron                    Action|Sci-Fi
# Aliens                      James Cameron          Action|Adventure|Sci-Fi
# The Abyss                   James Cameron  Adventure|Drama|Sci-Fi|Thriller

# %%
# 10
films_fr_above_8 = DATA[(DATA['country'] == 'France') & (DATA['imdb_score'] > 8)]
films_fr_above_8.head()[['country', 'imdb_score']]
# Out:
#             country  imdb_score
# movie_title
# Amélie       France         8.4
# The Pianist  France         8.5

# %%
# 11
condition1 = DATA['actor_1_name'] == 'Leonardo DiCaprio'
condition2 = DATA['actor_2_name'] == 'Leonardo DiCaprio'
leonardo_dicaprio = condition1 | condition2

action = DATA['genres'].str.contains("Action", na=False)

action_di_caprio = DATA[action & leonardo_dicaprio]

action_di_caprio.head()[['actor_1_name', 'actor_2_name']]
# Out:
#                                actor_1_name    actor_2_name
# movie_title
# Inception                 Leonardo DiCaprio       Tom Hardy
# Body of Lies              Leonardo DiCaprio  Simon McBurney
# The Man in the Iron Mask  Leonardo DiCaprio  Anne Parillaud
# The Quick and the Dead    Leonardo DiCaprio      Pat Hingle

# %%
# 12
western_slavery = DATA[DATA['genres'].str.contains('Western') & DATA['plot_keywords'].str.contains('slavery', na=False)]
western_slavery.head()[['plot_keywords', 'genres']]
# Out:
#                                                       plot_keywords  \
# movie_title
# Django Unchained  dynamite|historically inaccurate|ku klux klan|...
#
#                          genres
# movie_title
# Django Unchained  Drama|Western

# %%
# 13
eng_action_film_computer = DATA[(DATA['language'] == 'English') & (DATA['genres'].str.contains('Action')) & (DATA['plot_keywords'].str.contains('computer', na=False))]
eng_action_film_computer.head()[['language', 'genres', 'plot_keywords']]
# Out:
#                                              language  \
# movie_title
# The Matrix                                    English
# Skyfall                                       English
# Star Wars: Episode II - Attack of the Clones  English
# Mission: Impossible - Rogue Nation            English
# Swordfish                                     English
#
#                                                                        genres  \
# movie_title
# The Matrix                                                      Action|Sci-Fi
# Skyfall                                             Action|Adventure|Thriller
# Star Wars: Episode II - Attack of the Clones  Action|Adventure|Fantasy|Sci-Fi
# Mission: Impossible - Rogue Nation                  Action|Adventure|Thriller
# Swordfish                                               Action|Crime|Thriller
#
#                                                                                   plot_keywords
# movie_title
# The Matrix                                    artificial reality|computer|matrix|questioning...
# Skyfall                                       brawl|childhood home|computer cracker|intellig...
# Star Wars: Episode II - Attack of the Clones  martial arts|murdered before giving protagonis...
# Mission: Impossible - Rogue Nation              capture|computer hacker|mission|rogue agent|spy
# Swordfish                                     computer|secret agent|terrorism|told in flashb...

# %%
# 14
eng_germany_above_6 = DATA[(DATA['language'] == 'English') & (DATA['country'] == 'Germany') & (DATA['imdb_score'] > 6)]
eng_germany_above_6.head()[['language', 'country', 'imdb_score']]
# Out:
#                     language  country  imdb_score
# movie_title
# Blood Diamond        English  Germany         8.0
# Crash                English  Germany         7.9
# Cloud Atlas          English  Germany         7.5
# Lucky Number Slevin  English  Germany         7.8
# Red Dragon           English  Germany         7.2

# %%
# 15
films_actor1_jonathan_actor2_elizabeth = DATA[(DATA['actor_1_name'] == 'Jonathan Taylor Thomas') & (DATA['actor_2_name'] == 'Elizabeth Taylor')]
films_actor1_jonathan_actor2_elizabeth.head()[['actor_1_name', 'actor_2_name']]
# Out:
# Empty DataFrame
# Columns: [actor_1_name, actor_2_name]
# Index: []

# %% [markdown]
# # Ressources complémentaires
#
# Cours de Stéphane Mallat au collège de France : [Leçon inaugurale](https://www.college-de-france.fr/site/stephane-mallat/inaugural-lecture-2018-01-11-18h00.htm), [Cartographie de la science des données](https://www.college-de-france.fr/site/stephane-mallat/course-2018-01-17-09h30.htm)
#
# Livre [Data science : fondamentaux et études de cas - Machine learning avec Python et R](https://www.eyrolles.com/Chapitres/9782212142433/9782212142433.pdf) ([Version électronique accessible en ligne](https://unistra-scholarvox-com.scd-rproxy.u-strasbg.fr/book/88829994))

# %% [markdown]
# # Remarques
#
# ## Remarque 1
#
# La méthode `str.contains()` permet de vérifier si une chaîne de caractères est présente dans une autre chaîne de caractères. Par exemple, pour vérifier si la chaîne de caractères 'Batman' est présente dans la colonne `movie_title` :
# ```python
# df['movie_title'].str.contains('Batman')
# ```
# Elle nécessite parfois de préciser `na=False` pour éviter des erreurs, notamment lorsque qu'il manque des valeurs dans le tableau de données.
#
# ## Remarque 2
#
# La méthode `df.head()` n'affiche par défaut que les 5 premières lignes du tableau de données. On peut modifier ce nombre en passant un argument à la méthode, par exemple `df.head(10)` pour afficher les 10 premières lignes.
